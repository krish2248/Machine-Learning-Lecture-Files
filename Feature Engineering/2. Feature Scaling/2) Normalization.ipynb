# %% [markdown]
# # (ii)Normalization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Sandeep\python lerning\Feature Engineering\2) Feature Scaling\wine_data.csv")
df
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %%
df = pd.read_csv(r"C:\Users\Sandeep\python lerning\Feature Engineering\2) Feature Scaling\wine_data.csv",header=None,usecols=[0,1,3])
df.columns=['lable','Alcohol','Malic acid']
df
# Out:
#      lable  Alcohol  Malic acid
# 0        1    14.23        2.43
# 1        1    13.20        2.14
# 2        1    13.16        2.67
# 3        1    14.37        2.50
# 4        1    13.24        2.87
# ..     ...      ...         ...
# 173      3    13.71        2.45
# 174      3    13.40        2.48
# 175      3    13.27        2.26
# 176      3    13.17        2.37
# 177      3    14.13        2.74
#
# [178 rows x 3 columns]

# %%
y = df['lable']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: lable, Length: 178, dtype: int64

# %%
X = df.drop(columns='lable')
X
# Out:
#      Alcohol  Malic acid
# 0      14.23        2.43
# 1      13.20        2.14
# 2      13.16        2.67
# 3      14.37        2.50
# 4      13.24        2.87
# ..       ...         ...
# 173    13.71        2.45
# 174    13.40        2.48
# 175    13.27        2.26
# 176    13.17        2.37
# 177    14.13        2.74
#
# [178 rows x 2 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
X_scaler = scaler.fit_transform(X)
X_scaler
# Out:
# array([[0.84210526, 0.57219251],
#        [0.57105263, 0.4171123 ],
#        [0.56052632, 0.70053476],
#        [0.87894737, 0.60962567],
#        [0.58157895, 0.80748663],
#        [0.83421053, 0.5828877 ],
#        [0.88421053, 0.5828877 ],
#        [0.79736842, 0.6684492 ],
#        [1.        , 0.43315508],
#        [0.74473684, 0.48663102],
#        [0.80789474, 0.5026738 ],
#        [0.81315789, 0.51336898],
#        [0.71578947, 0.56149733],
#        [0.97894737, 0.55080214],
#        [0.88157895, 0.54545455],
#        [0.68421053, 0.71657754],
#        [0.86052632, 0.72727273],
#        [0.73684211, 0.67379679],
#        [0.83157895, 0.59893048],
#        [0.68684211, 0.64171123],
#        [0.79736842, 0.49197861],
#        [0.5       , 0.68983957],
#        [0.70526316, 0.53475936],
#        [0.47894737, 0.62032086],
#        [0.65      , 0.6684492 ],
#        [0.53157895, 0.99465241],
#        [0.62105263, 0.67379679],
#        [0.59736842, 0.4171123 ],
# ...

# %%
X_scaler = pd.DataFrame(X_scaler,columns=['Alcohol','Malic acid'])
X_scaler
# Out:
#       Alcohol  Malic acid
# 0    0.842105    0.572193
# 1    0.571053    0.417112
# 2    0.560526    0.700535
# 3    0.878947    0.609626
# 4    0.581579    0.807487
# ..        ...         ...
# 173  0.705263    0.582888
# 174  0.623684    0.598930
# 175  0.589474    0.481283
# 176  0.563158    0.540107
# 177  0.815789    0.737968
#
# [178 rows x 2 columns]

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.scatter(X['Alcohol'], X['Malic acid'],c='r')
plt.title("Before Scaling")

plt.subplot(1,2,2)
plt.scatter(X_scaler['Alcohol'], X_scaler['Malic acid'],c='r')
plt.title("After Scaling")

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X['Alcohol'], ax=ax1)
sns.kdeplot(X['Malic acid'], ax=ax1)

# after scaling
ax2.set_title('After Mean max Scaling')
sns.kdeplot(X_scaled['Alcohol'], ax=ax2)
sns.kdeplot(X_scaled['Malic acid'], ax=ax2)

plt.show()
# Out:
# C:\Users\Sandeep\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Sandeep\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 10
#       8 # after scaling
#       9 ax2.set_title('After Mean max Scaling')
# ---> 10 sns.kdeplot(X_scaled['Alcohol'], ax=ax2)
#      11 sns.kdeplot(X_scaled['Malic acid'], ax=ax2)
#      13 plt.show()
#
# NameError: name 'X_scaled' is not defined
