# %% [markdown]
# # (ii)Normalization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Helly\Desktop\coding\2) Feature Scaling\2) Feature Scaling\wine_data.csv")
df

# %%
df = pd.read_csv(r"C:\Users\Helly\Desktop\coding\2) Feature Scaling\2) Feature Scaling\wine_data.csv",header=None,usecols=[0,1,3])
df.columns=['lable','Alcohol','Malic acid']
df

# %%
y = df['lable']
y

# %%
X = df.drop(columns='lable')
X

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
X_scaler = scaler.fit_transform(X)
X_scaler

# %%
X_scaler = pd.DataFrame(X_scaler,columns=['Alcohol','Malic acid'])
X_scaler

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.scatter(X['Alcohol'], X['Malic acid'],c='r')
plt.title("Before Scaling")

plt.subplot(1,2,2)
plt.scatter(X_scaler['Alcohol'], X_scaler['Malic acid'],c='r')
plt.title("After Scaling")

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X['Alcohol'], ax=ax1)
sns.kdeplot(X['Malic acid'], ax=ax1)

# after scaling
ax2.set_title('After Mean max Scaling')
sns.kdeplot(X_scaled['Alcohol'], ax=ax2)
sns.kdeplot(X_scaled['Malic acid'], ax=ax2)

plt.show()
