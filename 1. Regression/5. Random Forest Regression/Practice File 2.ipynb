# %%
import pandas as pd
import numpy as np
import matplotlib_inline as plt
import sklearn 
import pickle
import warnings

# %%
df = pd.read_csv(r"C:\Users\sonik\Desktop\python lerning\ML\1) Regression\5) Random Forest Regression\Practical Codes\insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df['age'].unique()
# Out:
# array([19, 18, 28, 33, 32, 31, 46, 37, 60, 25, 62, 23, 56, 27, 52, 30, 34,
#        59, 63, 55, 22, 26, 35, 24, 41, 38, 36, 21, 48, 40, 58, 53, 43, 64,
#        20, 61, 44, 57, 29, 45, 54, 49, 47, 51, 42, 50, 39])

# %%
x = df.drop(columns='bmi')
y = df['bmi']

# %%
x = pd.get_dummies(data=x,columns=['age'],drop_first=True)

# %%
x.head()
# Out:
#       sex  children smoker     region      charges  age_19  age_20  age_21  \
# 0  female         0    yes  southwest  16884.92400    True   False   False
# 1    male         1     no  southeast   1725.55230   False   False   False
# 2    male         3     no  southeast   4449.46200   False   False   False
# 3    male         0     no  northwest  21984.47061   False   False   False
# 4    male         0     no  northwest   3866.85520   False   False   False
#
#    age_22  age_23  ...  age_55  age_56  age_57  age_58  age_59  age_60  \
# 0   False   False  ...   False   False   False   False   False   False
# 1   False   False  ...   False   False   False   False   False   False
# 2   False   False  ...   False   False   False   False   False   False
# 3   False   False  ...   False   False   False   False   False   False
# 4   False   False  ...   False   False   False   False   False   False
#
#    age_61  age_62  age_63  age_64
# 0   False   False   False   False
# ...

# %%
y.head()
# Out:
# 0    27.900
# 1    33.770
# 2    33.000
# 3    22.705
# 4    28.880
# Name: bmi, dtype: float64

# %%
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3, random_state = 0)

# %%
from sklearn.ensemble import RandomForestRegressor
regressior = RandomForestRegressor(random_state = 0)
regressior.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 from sklearn.ensemble import RandomForestRegressor
#       2 regressior = RandomForestRegressor(random_state = 0)
# ----> 3 regressior.fit(x_train, y_train)
#
# File c:\Users\sonik\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\sonik\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\ensemble\_forest.py:359, in BaseForest.fit(self, X, y, sample_weight)
#     356 if issparse(y):
# ...
