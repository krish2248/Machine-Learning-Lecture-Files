# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Helly\Desktop\coding\Helly\4) Machine Learning\1) Regression\1) Simple Linear Regression\Practical Codes\Salary_Data.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
X = df.iloc[:,t].values
y = df.iloc[:,-1].values

# %%
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
X = pd.DataFrame(X,columns=['YearsExperience'])
X
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
from sklearn.preprocessing import RobustScaler
rb = RobustScaler()
X = rb.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# # simple linear regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr = lr.predict(X_test)

# %% [markdown]
# # multipal linear regression

# %%
from sklearn.linear_model import LinearRegression
ml = LinearRegression()
ml.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_ml = ml.predict(X_test)

# %% [markdown]
# # polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
pr = LinearRegression()
pr.fit(X_train_poly,y_train)
# Out:
# LinearRegression()

# %%
y_pred_pr = pr.predict(X_test_poly)

# %% [markdown]
# # Decission tree

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_dt = dt.predict(X_test)

# %% [markdown]
# # random forest

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_rf = rf.predict(X_test)

# %% [markdown]
# # K nearest neighbour

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=4)
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
y_pred_knn = knn.predict(X_test)

# %% [markdown]
# # evalution

# %%
from sklearn.metrics import r2_score

# %%
lr = r2_score(y_test,y_pred_lr)
ml = r2_score(y_test,y_pred_ml)
pr = r2_score(y_test,y_pred_pr)
dt = r2_score(y_test,y_pred_dt)
rf = r2_score(y_test,y_pred_rf)
knn = r2_score(y_test,y_pred_knn)

print('simple linear :',lr)
print('miltipal linear :',ml)
print('polynomial :',pr)
print('decision tree :',dt)
print('random forest :',rf)
print('k nearest neighbour :',knn)
# Out:
# simple linear : 0.988169515729126
# miltipal linear : 0.988169515729126
# polynomial : 0.9882197351491805
# decision tree : 0.9764754205531827
# random forest : 0.9782190534211989
# k nearest neighbour : 0.9779401919627041
