# %%
import pickle

# %%
model = pickle.load(open(r'C:\Users\sonik\Desktop\Coding Cloud\Machine Learning\simple linear regression model 123',"rb"))

# %%
model.predict([[10]])
# Out:
# c:\Users\sonik\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([119309.25557305])

# %%
model.predict([[15]])
# Out:
# c:\Users\sonik\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([166004.66419212])
