# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Helly\Desktop\coding\Helly Intern (ML)\7) Machine Learning\2) Classification\1) Logistic Regression\Practical Codes\Social_Network_Ads.csv")
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
df.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
X = pd.DataFrame(X,columns=['Age', 'EstimatedSalary'])
X
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
from sklearn.preprocessing import RobustScaler
rb = RobustScaler()
X = rb.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# # simple linear regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr = lr.predict(X_test)

# %% [markdown]
# # multipal linear regression

# %%
from sklearn.linear_model import LinearRegression
ml = LinearRegression()
ml.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_ml = ml.predict(X_test)

# %% [markdown]
# # polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
pr = LinearRegression()
pr.fit(X_train_poly,y_train)
# Out:
# LinearRegression()

# %%
y_pred_pr = pr.predict(X_test_poly)

# %% [markdown]
# # Decission tree

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_dt = dt.predict(X_test)

# %% [markdown]
# # random forest

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_rf = rf.predict(X_test)

# %% [markdown]
# # K nearest neighbour

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=6)
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=6)

# %%
y_pred_knn = knn.predict(X_test)

# %% [markdown]
# # evalution

# %%
from sklearn.metrics import r2_score

# %%
lr = r2_score(y_test,y_pred_lr)
ml = r2_score(y_test,y_pred_ml)
pr = r2_score(y_test,y_pred_pr)
dt = r2_score(y_test,y_pred_dt)
rf = r2_score(y_test,y_pred_rf)
knn = r2_score(y_test,y_pred_knn)

print('simple linear :',lr)
print('miltipal linear :',ml)
print('polynomial :',pr)
print('decision tree :',dt)
print('random forest :',rf)
print('k nearest neighbour :',knn)
# Out:
# simple linear : 0.5973283861259658
# miltipal linear : 0.5973283861259658
# polynomial : 0.6856509956469068
# decision tree : 0.420062695924765
# random forest : 0.7474691309648207
# k nearest neighbour : 0.8188784395680948
